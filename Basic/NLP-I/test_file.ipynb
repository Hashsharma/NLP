# %%
pip install -U yt-dlp
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.12.8-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 70.6 kB/s eta 0:00:0000:0100:02m
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.12.8
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from yt_dlp import YoutubeDL

ydl_opts = {
    "quiet": True,
    "skip_download": True,
}

with YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(
        "https://www.youtube.com/@GoldminesTelefilms",
        download=False
    )

print(info.keys())
# Out:
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] VgPBhn77pp0: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] VgPBhn77pp0: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 6WpZVxGT8xY: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 6WpZVxGT8xY: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] UmGPzTkBwjI: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] UmGPzTkBwjI: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] Abtxr8argbM: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] Abtxr8argbM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] GzORwhUukcs: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] GzORwhUukcs: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] wliG1P9RMnY: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] wliG1P9RMnY: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 1FSuyZQ75-M: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 1FSuyZQ75-M: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] jMyQXnfmq7c: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] jMyQXnfmq7c: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] DHfFbJgFbDY: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] DHfFbJgFbDY: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] qdaeY_Ln6-Y: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] qdaeY_Ln6-Y: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] FMYIEKTJo0g: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] FMYIEKTJo0g: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] FeXOYIXvwes: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] FeXOYIXvwes: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] bSzy7TTQ9Lg: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] bSzy7TTQ9Lg: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] xH6lXWSZzPM: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] xH6lXWSZzPM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] b9BjL0YHTPY: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] b9BjL0YHTPY: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] ObKe48isccE: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] ObKe48isccE: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] XzDt4womSys: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] XzDt4womSys: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] lB7wQDumw0U: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] lB7wQDumw0U: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] TJL2q2dru-Y: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] TJL2q2dru-Y: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] kvDMeEjJpAI: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] kvDMeEjJpAI: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] CYg6MjR5Y9s: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] CYg6MjR5Y9s: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] f_rFUy3s3R0: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] f_rFUy3s3R0: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] aGXubUQ7JEo: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] aGXubUQ7JEo: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] m_H3NOc6-Ds: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] m_H3NOc6-Ds: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] TmzFxR6FLTc: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] TmzFxR6FLTc: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] p21X3QD9eEk: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] p21X3QD9eEk: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] nWvnLedPCUI: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] nWvnLedPCUI: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] Zv6Kx7Zl-jU: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] Zv6Kx7Zl-jU: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] nWwSGR_Lyc4: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] nWwSGR_Lyc4: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 3lVR_YvWCPw: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 3lVR_YvWCPw: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] v1eRIOBixn0: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] v1eRIOBixn0: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] bvp1ZTPbRA0: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] bvp1ZTPbRA0: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] CXqYuwyP6po: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] CXqYuwyP6po: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] eYSxW69r72Q: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] eYSxW69r72Q: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] uKSO216Xfds: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] uKSO216Xfds: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 3iC2kq_YimM: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 3iC2kq_YimM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] Yq6YoOcgwdM: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] Yq6YoOcgwdM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] XmDF3v8k0AM: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] XmDF3v8k0AM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] HZ9rmNDHMKg: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] HZ9rmNDHMKg: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] rkgw_CHH6p8: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] rkgw_CHH6p8: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 90pc_6TgGd8: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 90pc_6TgGd8: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] jeby2LFOn2Q: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] jeby2LFOn2Q: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] epYGo667EDo: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] epYGo667EDo: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] f75gcMlqhjI: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] f75gcMlqhjI: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] Wizdu1CnFdg: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] Wizdu1CnFdg: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] hcdM03r-OLU: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] hcdM03r-OLU: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] FmTYnSAbgwo: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] FmTYnSAbgwo: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] cUNkP1_9dRs: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] cUNkP1_9dRs: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] TExqrRk1bKI: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] TExqrRk1bKI: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 3lfLfOQfd-s: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 3lfLfOQfd-s: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] kvA8oUVeUpA: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] kvA8oUVeUpA: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] HSkwVMevucw: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] HSkwVMevucw: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] iTTrd8cPefA: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] iTTrd8cPefA: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] HZA-MFDaWBI: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] HZA-MFDaWBI: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 9syUBCJCHgM: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 9syUBCJCHgM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] HFD1YF6ib00: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] HFD1YF6ib00: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] d0dyhiOx1oM: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] d0dyhiOx1oM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] in9l3EmZ-w4: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] in9l3EmZ-w4: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 55m0ttxPkxg: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# ...
# WARNING: [youtube] 9AB0fF3AguE: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 9AB0fF3AguE: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 9cnw_HqiKjk: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 9cnw_HqiKjk: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] pfYYqdpmXkU: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] pfYYqdpmXkU: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] IOfPPJQdqI0: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] IOfPPJQdqI0: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] wixizJ5HCj4: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] wixizJ5HCj4: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] PDV1vkczRiM: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1696, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1695 try:
# -> 1696     return func(self, *args, **kwargs)
#    1697 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1831, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1830 try:
# -> 1831     ie_result = ie.extract(url)
#    1832 except UserNotLive as e:
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/extractor/common.py:762, in InfoExtractor.extract(self, url)
#     760 self.to_screen('Extracting URL: %s' % (
#     761     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 762 ie_result = self._real_extract(url)
#     763 if ie_result is None:
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/extractor/youtube/_video.py:3910, in YoutubeIE._real_extract(self, url)
#    3904             reason = (
#    3905                 f'{remove_end(reason.strip(), ".")}. {"Your account" if self.is_authenticated else "The current session"} '
#    3906                 f'has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay '
#    3907                 f'between video requests to avoid exceeding the rate limit. For more information, refer to  '
#    3908                 f'https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later'
#    3909             )
# -> 3910         self.raise_no_formats(reason, expected=True)
#    3912 keywords = get_first(video_details, 'keywords', expected_type=list) or []
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/extractor/common.py:1274, in InfoExtractor.raise_no_formats(self, msg, expected, video_id)
#    1273 else:
# -> 1274     raise ExtractorError(msg, expected=expected, video_id=video_id)
#
# ExtractorError: [youtube] PDV1vkczRiM: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# Cell In[2], line 9
#       3 ydl_opts = {
#       4     "quiet": True,
#       5     "skip_download": True,
#       6 }
#       8 with YoutubeDL(ydl_opts) as ydl:
# ----> 9     info = ydl.extract_info(
#      10         "https://www.youtube.com/@GoldminesTelefilms",
#      11         download=False
#      12     )
#      14 print(info.keys())
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1685, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1683             raise ExistingVideoReached
#    1684         break
# -> 1685     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1686 else:
#    1687     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1696, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1694 while True:
#    1695     try:
# -> 1696         return func(self, *args, **kwargs)
#    1697     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1698         raise
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1852, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1850 if process:
#    1851     self._wait_for_video(ie_result)
# -> 1852     return self.process_ie_result(ie_result, download, extra_info)
#    1853 else:
#    1854     return ie_result
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1981, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1979 self._sanitize_thumbnails(ie_result)
#    1980 try:
# -> 1981     return self.__process_playlist(ie_result, download)
#    1982 finally:
#    1983     self._playlist_level -= 1
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:2129, in YoutubeDL.__process_playlist(self, ie_result, download)
#    2123     continue
#    2125 self.to_screen(
#    2126     f'[download] Downloading item {self._format_screen(i + 1, self.Styles.ID)} '
#    2127     f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
# -> 2129 entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2130     'playlist_index': playlist_index,
#    2131     'playlist_autonumber': i + 1,
#    2132 }, extra))
#    2133 if not entry_result:
#    2134     failures += 1
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1696, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1694 while True:
#    1695     try:
# -> 1696         return func(self, *args, **kwargs)
#    1697     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1698         raise
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:2161, in YoutubeDL.__process_iterable_entry(self, entry, download, extra_info)
#    2159 @_handle_extraction_exceptions
#    2160 def __process_iterable_entry(self, entry, download, extra_info):
# -> 2161     return self.process_ie_result(
#    2162         entry, download=download, extra_info=extra_info)
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1981, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1979 self._sanitize_thumbnails(ie_result)
#    1980 try:
# -> 1981     return self.__process_playlist(ie_result, download)
#    1982 finally:
#    1983     self._playlist_level -= 1
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:2129, in YoutubeDL.__process_playlist(self, ie_result, download)
#    2123     continue
#    2125 self.to_screen(
#    2126     f'[download] Downloading item {self._format_screen(i + 1, self.Styles.ID)} '
#    2127     f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
# -> 2129 entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2130     'playlist_index': playlist_index,
#    2131     'playlist_autonumber': i + 1,
#    2132 }, extra))
#    2133 if not entry_result:
#    2134     failures += 1
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1696, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1694 while True:
#    1695     try:
# -> 1696         return func(self, *args, **kwargs)
#    1697     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1698         raise
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:2161, in YoutubeDL.__process_iterable_entry(self, entry, download, extra_info)
#    2159 @_handle_extraction_exceptions
#    2160 def __process_iterable_entry(self, entry, download, extra_info):
# -> 2161     return self.process_ie_result(
#    2162         entry, download=download, extra_info=extra_info)
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1931, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1927     return ie_result
#    1928 elif result_type == 'url':
#    1929     # We have to add extra_info to the results because it may be
#    1930     # contained in a playlist
# -> 1931     return self.extract_info(
#    1932         ie_result['url'], download,
#    1933         ie_key=ie_result.get('ie_key'),
#    1934         extra_info=extra_info)
#    1935 elif result_type == 'url_transparent':
#    1936     # Use the information from the embedding page
#    1937     info = self.extract_info(
#    1938         ie_result['url'], ie_key=ie_result.get('ie_key'),
#    1939         extra_info=extra_info, download=False, process=False)
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1685, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1683             raise ExistingVideoReached
#    1684         break
# -> 1685     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1686 else:
#    1687     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1714, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1712     self.report_error(msg)
#    1713 except ExtractorError as e:  # An error we somewhat expected
# -> 1714     self.report_error(str(e), e.format_traceback())
#    1715 except Exception as e:
#    1716     if self.params.get('ignoreerrors'):
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1154, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1149 def report_error(self, message, *args, **kwargs):
#    1150     """
#    1151     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1152     in red if stderr is a tty file.
#    1153     """
# -> 1154     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File /media/scientist-anand/volume/mr_document/all_venv/chatterbox_venv/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1093, in YoutubeDL.trouble(self, message, tb, is_error)
#    1091     else:
#    1092         exc_info = sys.exc_info()
# -> 1093     raise DownloadError(message, exc_info)
#    1094 self._download_retcode = 1
#
# DownloadError: ERROR: [youtube] PDV1vkczRiM: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later

# %%
import time
import random
from yt_dlp import YoutubeDL
import concurrent.futures
from functools import partial

class YouTubeChannelExtractor:
    def __init__(self, channel_url, max_workers=3, min_delay=1, max_delay=3):
        """
        Initialize the YouTube channel extractor with rate limiting controls
        
        Args:
            channel_url: YouTube channel URL
            max_workers: Number of concurrent workers (be conservative)
            min_delay: Minimum delay between requests in seconds
            max_delay: Maximum delay between requests in seconds
        """
        self.channel_url = channel_url
        self.max_workers = max_workers
        self.min_delay = min_delay
        self.max_delay = max_delay
        
        # Base options for channel info extraction
        self.channel_opts = {
            "quiet": True,
            "skip_download": True,
            "extract_flat": True,  # Get basic info without downloading
            "playlistend": 50,  # Adjust based on your needs
        }
        
        # Options for video details extraction
        self.video_opts = {
            "quiet": True,
            "skip_download": True,
            "extract_flat": False,
        }
    
    def get_channel_videos(self):
        """Get list of video IDs from channel"""
        with YoutubeDL(self.channel_opts) as ydl:
            try:
                info = ydl.extract_info(self.channel_url, download=False)
                if 'entries' in info:
                    return [entry['id'] for entry in info['entries'] if entry]
                return []
            except Exception as e:
                print(f"Error getting channel info: {e}")
                return []
    
    def get_video_details(self, video_id):
        """Get details for a single video with delay"""
        # Random delay to avoid rate limiting
        time.sleep(random.uniform(self.min_delay, self.max_delay))
        
        try:
            with YoutubeDL(self.video_opts) as ydl:
                info = ydl.extract_info(video_id, download=False)
                
                # Extract only the required fields
                video_data = {
                    'youtube_id': info.get('id'),
                    'title': info.get('title'),
                    'duration': info.get('duration'),
                    'tags': info.get('tags', []),
                    'images': {
                        'thumbnail': info.get('thumbnail'),
                        'thumbnails': info.get('thumbnails', [])
                    }
                }
                return video_data
        except Exception as e:
            print(f"Error getting video {video_id}: {e}")
            return None
    
    def extract_all_videos(self):
        """Extract all videos from channel with rate limiting"""
        print("Fetching video list from channel...")
        video_ids = self.get_channel_videos()
        
        if not video_ids:
            print("No videos found or error fetching channel")
            return []
        
        print(f"Found {len(video_ids)} videos. Starting extraction...")
        
        # Use ThreadPoolExecutor for concurrent extraction
        all_video_data = []
        
        with concurrent.futures.ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            # Create futures for all video IDs
            futures = []
            for video_id in video_ids:
                future = executor.submit(self.get_video_details, video_id)
                futures.append(future)
                
                # Small delay between submitting tasks
                time.sleep(0.1)
            
            # Collect results as they complete
            completed = 0
            for future in concurrent.futures.as_completed(futures):
                result = future.result()
                if result:
                    all_video_data.append(result)
                completed += 1
                if completed % 5 == 0:
                    print(f"Progress: {completed}/{len(video_ids)} videos processed")
                
                # Optional: Save progress periodically
                if completed % 20 == 0:
                    self._save_progress(all_video_data, completed)
        
        print(f"Extraction complete! Processed {len(all_video_data)} videos")
        return all_video_data
    
    def _save_progress(self, data, count):
        """Optional: Save progress to file"""
        import json
        with open(f'progress_{count}.json', 'w') as f:
            json.dump(data, f, indent=2)
        print(f"Progress saved after {count} videos")

# Alternative: Sequential extraction with adaptive delays
def extract_with_adaptive_delay(channel_url, batch_size=10, initial_delay=2):
    """
    Extract videos with adaptive delay - increases delay if errors occur
    """
    channel_extractor = YouTubeChannelExtractor(channel_url)
    video_ids = channel_extractor.get_channel_videos()
    
    all_data = []
    delay = initial_delay
    error_count = 0
    
    for i, video_id in enumerate(video_ids):
        print(f"Processing video {i+1}/{len(video_ids)}")
        
        try:
            # Apply current delay
            time.sleep(delay)
            
            # Get video details
            video_data = channel_extractor.get_video_details(video_id)
            if video_data:
                all_data.append(video_data)
                error_count = 0  # Reset error count on success
                
                # Gradually decrease delay if things are going well
                if error_count == 0 and delay > 1:
                    delay = max(1, delay * 0.9)  # Reduce delay by 10%
            else:
                error_count += 1
                
        except Exception as e:
            print(f"Error on video {video_id}: {e}")
            error_count += 1
        
        # If we get multiple errors, increase delay
        if error_count >= 3:
            delay = min(10, delay * 1.5)  # Increase by 50%, max 10 seconds
            print(f"Increased delay to {delay:.1f} seconds due to errors")
            error_count = 0  # Reset after adjusting
        
        # Save batch
        if (i + 1) % batch_size == 0:
            import json
            with open(f'batch_{(i+1)//batch_size}.json', 'w') as f:
                json.dump(all_data, f, indent=2)
            print(f"Saved batch {(i+1)//batch_size}")
    
    return all_data

# Fastest option (use with caution - higher risk of rate limiting)
def fast_extract(channel_url, max_videos=100):
    """
    Fast extraction with minimal delay - use only if you have high rate limits
    """
    opts = {
        "quiet": True,
        "skip_download": True,
        "extract_flat": False,
        "playlistend": max_videos,
        "ignoreerrors": True,  # Continue on errors
    }
    
    all_data = []
    
    with YoutubeDL(opts) as ydl:
        info = ydl.extract_info(channel_url, download=False)
        
        if 'entries' in info:
            for entry in info['entries']:
                if entry:  # Skip None entries from errors
                    video_data = {
                        'youtube_id': entry.get('id'),
                        'title': entry.get('title'),
                        'duration': entry.get('duration'),
                        'tags': entry.get('tags', []),
                        'images': {
                            'thumbnail': entry.get('thumbnail'),
                            'thumbnails': entry.get('thumbnails', [])
                        }
                    }
                    all_data.append(video_data)
                    
                    # Very small delay
                    time.sleep(0.5)
    
    return all_data

# %%
# Usage example:
data = None
if __name__ == "__main__":
    # Method 1: Conservative with rate limiting
    extractor = YouTubeChannelExtractor(
        "https://www.youtube.com/@GoldminesTelefilms",
        max_workers=2,  # Fewer workers = less likely to be rate limited
        min_delay=1.5,
        max_delay=3
    )
    data = extractor.extract_all_videos()
    
    # Method 2: Adaptive delay (good balance)
    # data = extract_with_adaptive_delay("https://www.youtube.com/@channelname")
    
    # Method 3: Fast extraction (risky)
    # data = fast_extract("https://www.youtube.com/@channelname", max_videos=50)
    
    # Print results
    print(f"\nExtracted {len(data)} videos")
    if data:
        print("\nFirst video details:")
        import json
        print(json.dumps(data[0], indent=2))
# Out:
# Fetching video list from channel...
# Found 2 videos. Starting extraction...
# ERROR: [generic] 'UCyoXW-Dse7fURq30EWl_CUA' is not a valid URL
# Error getting video UCyoXW-Dse7fURq30EWl_CUA: ERROR: [generic] 'UCyoXW-Dse7fURq30EWl_CUA' is not a valid URL
# ERROR: [generic] 'UCyoXW-Dse7fURq30EWl_CUA' is not a valid URL
# Error getting video UCyoXW-Dse7fURq30EWl_CUA: ERROR: [generic] 'UCyoXW-Dse7fURq30EWl_CUA' is not a valid URL
# Extraction complete! Processed 0 videos
#
# Extracted 0 videos

# %%
import time
import random
import json
from yt_dlp import YoutubeDL

class GoldminesTelefilmsExtractor:
    def __init__(self, max_videos=50):
        """
        Initialize extractor for Goldmines Telefilms channel
        
        Args:
            max_videos: Maximum number of videos to extract
        """
        self.channel_url = "https://www.youtube.com/@GoldminesTelefilms/videos"
        self.max_videos = max_videos
        
        # Optimized options for this specific channel
        self.channel_opts = {
            "quiet": True,
            "skip_download": True,
            "ignoreerrors": True,
            "extract_flat": True,
            "playlistend": max_videos,
            "sleep_interval": 2,
            "sleep_interval_requests": 1,
            "no_warnings": True,  # Suppress warnings for cleaner output
        }
        
        # Video extraction options with better rate limiting
        self.video_opts = {
            "quiet": True,
            "skip_download": True,
            "ignoreerrors": True,
            "no_warnings": True,
            "extract_flat": False,
            "sleep_interval": 3,
            "sleep_interval_requests": 2,
            "max_sleep_interval": 15,
        }
    
    def get_video_list(self):
        """Get list of videos from the channel"""
        print("Fetching video list from Goldmines Telefilms channel...")
        
        with YoutubeDL(self.channel_opts) as ydl:
            try:
                info = ydl.extract_info(self.channel_url, download=False)
                
                if not info:
                    print("No data received from channel")
                    return []
                
                videos = []
                if 'entries' in info:
                    for entry in info['entries']:
                        if entry and 'id' in entry:
                            video_url = f"https://www.youtube.com/watch?v={entry['id']}"
                            videos.append({
                                'url': video_url,
                                'id': entry['id'],
                                'title': entry.get('title', 'Unknown'),
                            })
                
                print(f"Found {len(videos)} videos")
                return videos
                
            except Exception as e:
                print(f"Error fetching channel: {e}")
                return []
    
    def extract_video_with_retry(self, video_info, retry_count=0):
        """
        Extract a single video with retry logic
        
        Args:
            video_info: Dictionary with video URL and ID
            retry_count: Current retry attempt
        """
        max_retries = 2
        
        # Progressive delay: 3s first, 10s second, 30s third attempt
        base_delay = [3, 10, 30][min(retry_count, 2)]
        jitter = random.uniform(0.5, 2.0)
        delay = base_delay * jitter
        
        print(f"  Waiting {delay:.1f}s before request (attempt {retry_count + 1})...")
        time.sleep(delay)
        
        try:
            with YoutubeDL(self.video_opts) as ydl:
                info = ydl.extract_info(video_info['url'], download=False)
                
                if not info:
                    print(f"  No data for video {video_info['id']}")
                    return None
                
                video_data = {
                    'youtube_id': info.get('id'),
                    'title': info.get('title', 'Unknown Title'),
                    'duration': info.get('duration', 0),
                    'tags': info.get('tags', []),
                    'images': {
                        'thumbnail': info.get('thumbnail'),
                        'thumbnails': info.get('thumbnails', [])
                    }
                }
                
                print(f"  ✓ Extracted: {video_data['title'][:60]}...")
                return video_data
                
        except Exception as e:
            error_msg = str(e).lower()
            
            # Check for rate limiting
            if any(keyword in error_msg for keyword in ['rate', '429', 'unavailable', 'limit']):
                if retry_count < max_retries:
                    print(f"  Rate limited. Retrying in {delay*2:.1f}s...")
                    return self.extract_video_with_retry(video_info, retry_count + 1)
                else:
                    print(f"  Max retries exceeded for video {video_info['id']}")
                    return None
            else:
                print(f"  Error extracting video {video_info['id']}: {str(e)[:100]}")
                return None
    
    def extract_channel_data(self):
        """Main method to extract all channel data"""
        print("=" * 60)
        print("Goldmines Telefilms Channel Extractor")
        print("=" * 60)
        
        # Step 1: Get video list
        videos = self.get_video_list()
        
        if not videos:
            print("No videos found. Exiting.")
            return []
        
        print(f"\nStarting extraction of {len(videos)} videos...")
        print("-" * 60)
        
        all_data = []
        processed = 0
        successful = 0
        
        # Step 2: Extract each video with delays
        for i, video in enumerate(videos):
            processed += 1
            print(f"\n[{i+1}/{len(videos)}] Processing: {video['title'][:50]}...")
            print(f"  Video ID: {video['id']}")
            
            video_data = self.extract_video_with_retry(video)
            
            if video_data:
                all_data.append(video_data)
                successful += 1
                print(f"  Status: SUCCESS (Total: {successful})")
            else:
                print(f"  Status: FAILED")
            
            # Save progress every 5 videos
            if (i + 1) % 5 == 0:
                self._save_progress(all_data, i + 1)
                
                # Longer break every 10 videos
                if (i + 1) % 10 == 0:
                    long_break = random.uniform(15, 25)
                    print(f"\n{'-'*40}")
                    print(f"Taking extended break: {long_break:.1f} seconds")
                    print(f"{'-'*40}")
                    time.sleep(long_break)
        
        # Final save
        self._save_final_results(all_data)
        
        # Summary
        print("\n" + "=" * 60)
        print("EXTRACTION COMPLETE")
        print("=" * 60)
        print(f"Total videos processed: {processed}")
        print(f"Successfully extracted: {successful}")
        print(f"Failed: {processed - successful}")
        print(f"Success rate: {(successful/processed*100):.1f}%")
        
        if all_data:
            print(f"\nSample data from first video:")
            print(json.dumps(all_data[0], indent=2, ensure_ascii=False))
        
        return all_data
    
    def _save_progress(self, data, count):
        """Save progress to file"""
        filename = f'goldmines_progress_{count}.json'
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"  Progress saved to {filename}")
    
    def _save_final_results(self, data):
        """Save final results"""
        from datetime import datetime
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f'goldmines_telefilms_{timestamp}.json'
        
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump({
                'channel': 'Goldmines Telefilms',
                'url': self.channel_url,
                'extracted_at': timestamp,
                'total_videos': len(data),
                'videos': data
            }, f, ensure_ascii=False, indent=2)
        
        print(f"\nFinal results saved to {filename}")
        
        # Also create a CSV for easy viewing
        self._create_csv(data, timestamp)
    
    def _create_csv(self, data, timestamp):
        """Create CSV file for easy viewing"""
        import csv
        
        csv_filename = f'goldmines_telefilms_{timestamp}.csv'
        
        with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            fieldnames = ['youtube_id', 'title', 'duration', 'tags_count', 'thumbnail']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            
            writer.writeheader()
            for video in data:
                writer.writerow({
                    'youtube_id': video.get('youtube_id', ''),
                    'title': video.get('title', ''),
                    'duration': video.get('duration', 0),
                    'tags_count': len(video.get('tags', [])),
                    'thumbnail': video.get('images', {}).get('thumbnail', '')
                })
        
        print(f"CSV file created: {csv_filename}")

# Quick test function
def quick_test(limit=5):
    """Quick test with small number of videos"""
    print("Running quick test with 5 videos...")
    extractor = GoldminesTelefilmsExtractor(max_videos=limit)
    
    # Test getting video list only
    videos = extractor.get_video_list()
    
    if videos:
        print(f"\nFirst {min(3, len(videos))} videos found:")
        for i, video in enumerate(videos[:3]):
            print(f"{i+1}. {video['title'][:50]}... (ID: {video['id']})")
        
        # Test extracting first video
        print(f"\nTesting extraction of first video...")
        test_video = extractor.extract_video_with_retry(videos[0])
        
        if test_video:
            print("\n✓ Test successful!")
            print(f"Title: {test_video['title']}")
            print(f"Duration: {test_video['duration']} seconds")
            print(f"Tags: {len(test_video['tags'])} tags")
            print(f"Thumbnail: {test_video['images']['thumbnail'][:80]}...")
            return True
        else:
            print("\n✗ Test failed - might be rate limited")
            return False
    return False

# Batch extraction with resume capability
def batch_extract(batch_size=10, start_from=0):
    """
    Extract in batches with resume capability
    
    Args:
        batch_size: Number of videos per batch
        start_from: Starting index (for resuming)
    """
    extractor = GoldminesTelefilmsExtractor(max_videos=100)  # Get up to 100 videos
    videos = extractor.get_video_list()
    
    if not videos:
        return []
    
    # Slice videos for this batch
    end_idx = min(start_from + batch_size, len(videos))
    batch_videos = videos[start_from:end_idx]
    
    print(f"\nProcessing batch: videos {start_from+1} to {end_idx}")
    
    batch_data = []
    for i, video in enumerate(batch_videos):
        print(f"\n[{i+1}/{len(batch_videos)}] Processing: {video['title'][:50]}...")
        
        video_data = extractor.extract_video_with_retry(video)
        if video_data:
            batch_data.append(video_data)
        
        # Save batch results
        if (i + 1) % 5 == 0:
            filename = f'batch_{start_from+1}_to_{start_from+i+1}.json'
            with open(filename, 'w', encoding='utf-8') as f:
                json.dump(batch_data, f, ensure_ascii=False, indent=2)
    
    return batch_data

# %%
import pandas as pd

# Load JSON list from file
df = pd.read_json("../../resource/youtube_data copy.json")

# Flatten nested images field
df["thumbnail"] = df["images"].apply(lambda x: x.get("thumbnail"))
df = df.drop(columns=["images"])

# Add playlist_id column based on duration (< 15 minutes)
df["playlist_id"] = df["duration"].apply(
    lambda x: 3 if x < 900 else None  # None → MySQL NULL
)

# Save to CSV
df.to_csv("../../resource/youtube_goldmines_data.csv", index=False)

print(df)
# Out:
#         youtube_id                                              title  \
# 0      VgPBhn77pp0  मिर्नालिनी रवि अथर्व को चैंलेंजे करती है | Gad...
# 1      6WpZVxGT8xY  सूर्या दिलीप ताहिल से मिलने आया l Khatarnak Kh...
# 2      UmGPzTkBwjI  विजय को देख कर इस गुंडे की बोलती बंद हो गई | B...
# 3      Abtxr8argbM  अजय जिस लड़की से प्यार करता है उसपर उसके बड़े ...
# 4      wliG1P9RMnY  इस औरत को पूरा यकीन है कि उसकी बेटी आज भी जिंद...
# ...            ...                                                ...
# 11167  bJ7Fvju9DFs  The Return of Rebel 2 (Billa) Hindi Dubbed Ful...
# 11168  TgTibdqWHTg  Indian Soldier Never On Holiday (Thupakki) Hin...
# 11169  EMWM2uN8WCQ  Jawaan (2018) New Released Hindi Dubbed Full M...
# 11170  1m-M62XN6kM  Apradhi Kaun (Dongala Mutha) 2018 Official Hin...
# 11171  bi2ZGhdUnFE  Jamai Raja (Mappillai) Full Hindi Dubbed Movie...
#
#        duration                                          thumbnail  \
# 0           745  https://i.ytimg.com/vi/VgPBhn77pp0/maxresdefau...
# 1           760  https://i.ytimg.com/vi/6WpZVxGT8xY/maxresdefau...
# 2           760  https://i.ytimg.com/vi/UmGPzTkBwjI/maxresdefau...
# 3           740  https://i.ytimg.com/vi/Abtxr8argbM/maxresdefau...
# 4           731  https://i.ytimg.com/vi/wliG1P9RMnY/maxresdefau...
# ...         ...                                                ...
# 11167      7588  https://i.ytimg.com/vi/bJ7Fvju9DFs/maxresdefau...
# 11168      8219   https://i.ytimg.com/vi/TgTibdqWHTg/sddefault.jpg
# 11169      6261  https://i.ytimg.com/vi/EMWM2uN8WCQ/maxresdefau...
# 11170        68  https://i.ytimg.com/vi/1m-M62XN6kM/maxresdefau...
# 11171      8050  https://i.ytimg.com/vi/bi2ZGhdUnFE/maxresdefau...
#
#        playlist_id
# 0              3.0
# 1              3.0
# 2              3.0
# 3              3.0
# 4              3.0
# ...            ...
# 11167          NaN
# 11168          NaN
# 11169          NaN
# 11170          3.0
# 11171          NaN
#
# [11172 rows x 5 columns]
